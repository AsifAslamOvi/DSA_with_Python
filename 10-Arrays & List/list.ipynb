# %%
import sys

l1 =[]

print("Initial size: ", sys.getsizeof(l1))

for i in range(0, 17):
    l1.append(i)
    print(f"{i} --> {sys.getsizeof(l1)}")
# Out:
# Initial size:  56
# 0 --> 88
# 1 --> 88
# 2 --> 88
# 3 --> 88
# 4 --> 120
# 5 --> 120
# 6 --> 120
# 7 --> 120
# 8 --> 184
# 9 --> 184
# 10 --> 184
# 11 --> 184
# 12 --> 184
# 13 --> 184
# 14 --> 184
# 15 --> 184
# 16 --> 248

# %%
l2 = []
a = 1
l2.append(1)

print(id(1))
print(id(a))
print(id(l2[0]))
# Out:
# 140734332851112
# 140734332851112
# 140734332851112

# %%
l2 = []
a = 1
l2.append(1)

print(id(1))
a = 2
print(id(a))
print(id(l2[0]))

l2.append("python")
print(l2)
# Out:
# 140734332851112
# 140734332851144
# 140734332851112
# [1, 'python']
