# %% [markdown]
# # Binary Search
#
# ##  Definition
#
# **Binary Search** is an efficient searching algorithm that finds the position of a target value in a **sorted list** by repeatedly dividing the search space into halves.
#
# - In simple words:
# It **eliminates half of the data in each step**.
#
# ---
#
# ##  Requirements
#
# * The list **must be sorted** (ascending or descending)
#
# ---
#
# ##  How It Works
#
# 1. Find the middle element
# 2. Compare it with the target
# 3. If equal → return index
# 4. If target is smaller → search left half
# 5. If target is larger → search right half
# 6. Repeat until found or search space is empty
#
# ---
#
# ##  Algorithm (Concept)
#
# ```python id="0tsv2w"
# low = 0
# high = n - 1
#
# while low <= high:
#     mid = (low + high) // 2
#
#     if arr[mid] == target:
#         return mid
#     elif arr[mid] < target:
#         low = mid + 1
#     else:
#         high = mid - 1
#
# return -1
# ```
#
# ---
#
# ##  Iterative Implementation
#
# ```python id="5dw5x3"
# def binary_search(arr, target):
#     low = 0
#     high = len(arr) - 1
#
#     while low <= high:
#         mid = (low + high) // 2
#
#         if arr[mid] == target:
#             return mid
#         elif arr[mid] < target:
#             low = mid + 1
#         else:
#             high = mid - 1
#
#     return -1
# ```
#
# ---
#
# ##  Example Usage
#
# ```python id="egds9v"
# numbers = [10, 20, 30, 40, 50]
#
# result = binary_search(numbers, 30)
#
# print("Index:", result)
# ```
#
# ### Output:
#
# ```id="mbdpm6"
# Index: 2
# ```
#
# ---
#
# ##  Step-by-Step Dry Run
#
# Search for `30` in:
#
# ```id="98gl7c"
# [10, 20, 30, 40, 50]
# ```
#
# | Step | low | high | mid | Element | Result  |
# | ---- | --- | ---- | --- | ------- | ------- |
# | 1    | 0   | 4    | 2   | 30      | Found   |
#
# ---
#
# ### Another Example (Target = 40)
#
# | Step | low | high | mid | Element | Action       |
# | ---- | --- | ---- | --- | ------- | ------------ |
# | 1    | 0   | 4    | 2   | 30      | Search right |
# | 2    | 3   | 4    | 3   | 40      | Found        |
#
# ---
#
# ##  Recursive Implementation
#
# ```python id="x0m18y"
# def binary_search_recursive(arr, low, high, target):
#     if low > high:
#         return -1
#
#     mid = (low + high) // 2
#
#     if arr[mid] == target:
#         return mid
#     elif arr[mid] < target:
#         return binary_search_recursive(arr, mid + 1, high, target)
#     else:
#         return binary_search_recursive(arr, low, mid - 1, target)
# ```
#
# ---
#
# ##  Advantages
#
# 1. Very fast and efficient
# 2. Reduces search space by half each time
# 3. Suitable for large datasets
#
# ---
#
# ##  Disadvantages
#
# 1. Requires sorted data
# 2. Slightly more complex than linear search
# 3. Not suitable for small datasets
#
# ---
#
# ##  Time Complexity
#
# | Case         | Complexity |
# | ------------ | ---------- |
# | Best Case    | O(1)       |
# | Average Case | O(log n)   |
# | Worst Case   | O(log n)   |
#
# ---
#
# ##  Space Complexity
#
# ### Iterative:
#
# ```id="y9fvl3"
# O(1)
# ```
#
# ### Recursive:
#
# ```id="n22km2"
# O(log n)
# ```
#
# ---
#
# ##  Binary Search vs Linear Search
#
# | Feature          | Binary Search    | Linear Search   |
# | ---------------- | ---------------- | --------------- |
# | Data Requirement | Must be sorted   | No need to sort |
# | Speed            | Fast             | Slow            |
# | Complexity       | O(log n)         | O(n)            |
# | Approach         | Divide & conquer | Sequential      |
#
# ---
#
# ##  Real-Life Example
#
# ```python id="e3kbzi"
# marks = [30, 40, 50, 60, 70, 80]
#
# target = 60
#
# index = binary_search(marks, target)
#
# if index != -1:
#     print("Found at index:", index)
# else:
#     print("Not found")
# ```
#
# ---
#
# ##  Important Notes
#
# * Always ensure the list is sorted before applying binary search
# * Use `(low + high) // 2` to find middle index
# * Faster than linear search for large data
# * Based on **divide and conquer** technique
#
# ---
#
# #  Summary
#
# * Binary search works on sorted data
# * Divides search space into halves
# * Time complexity: O(log n)
# * Much faster than linear search
# * Widely used in searching large datasets

# %%
def binary_search(arr, target):
    low = 0
    high = len(arr) - 1
    while low <= high:
        mid = (low + high) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
    return -1 

sorted_list = [10, 23, 35, 45, 63, 70, 90]
target = 63

result = binary_search(sorted_list, target)
if result != -1:
    print(f"Element found at index: {result}")
else:
    print("Element not found in the list.")
# Out:
# Element found at index: 4
